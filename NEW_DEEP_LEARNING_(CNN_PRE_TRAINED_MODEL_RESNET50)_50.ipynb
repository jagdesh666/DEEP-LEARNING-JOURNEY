# %%
from tensorflow.keras.applications import ResNet50
import tensorflow.keras.preprocessing.image as img_proc
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model = ResNet50(weights='imagenet')

# %%
img_path = 'chair.jfif'
img = img_proc.load_img(img_path, target_size=(224, 224))
x = img_proc.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

# %%
preds = model.predict(x)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %%
print('Predicted:', decode_predictions(preds, top=3)[0])
# Out:
# Predicted: [('n03376595', 'folding_chair', np.float32(0.6813784)), ('n03201208', 'dining_table', np.float32(0.09153367)), ('n03179701', 'desk', np.float32(0.07881971))]
